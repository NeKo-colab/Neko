# %% [markdown]
# # Usage
#
# This notebook provides the steps to build a network starting from a list of genes, and using the default functionalities of NeKo.

# %%
# %%time
from neko.core.network import Network
from neko._visual.visualize_network import NetworkVisualizer
import omnipath as op
# Out:
# [2026-04-28 19:38:25] [DEBUG] [pkg_infra.session        ] ▸ Using app logger: default
# [2026-04-28 19:38:25] [DEBUG] [pkg_infra.session        ] ▸ Session time initialized: utc=2026-04-28 17:38:25.553811+00:00, local=2026-04-28 19:38:25.553811+02:00, timezone=CEST
# [2026-04-28 19:38:25] [DEBUG] [pkg_infra.session        ] ▸ Location lookup skipped
# [2026-04-28 19:38:25] [INFO ] [pkg_infra.session        ] ▸ Creating new session...
# [2026-04-28 19:38:25] [INFO ] [pkg_infra.session        ] ▸ Session has been created
# [2026-04-28 19:38:25] [WARNING] [dlmachine._metadata      ] ▸ No local pyproject metadata found, trying installed metadata
# [2026-04-28 19:38:25] [DEBUG] [pkg_infra.session        ] ▸ get_session called with workspace=., include_location=False, config_path=None
# [2026-04-28 19:38:25] [INFO ] [pkg_infra.session        ] ▸ Initialization of a session:
# [2026-04-28 19:38:25] [INFO ] [pkg_infra.session        ] ▸ Reusing existing session
# [2026-04-28 19:38:25] [INFO ] [pkg_infra.session        ] ▸   hostname: nina-zenbook
#   username: nina
#   workspace: /home/nina/Dev_Projects/Neko/notebooks
#   id: 0d0756eb-10d9-4b49-8ce7-89916bd29314
#   started_at_utc: 2026-04-28 17:38:25.553811+00:00
#   started_at_local: 2026-04-28 19:38:25.553811+02:00
#   timezone: CEST
#   location: None
# [2026-04-28 19:38:25] [DEBUG] [pkg_infra.data           ] ▸ Loading built-in data `main.yaml` from module `cachedir`; path: `/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/cachedir/_data/main.yaml`.
# Downloading: 100%|██████████| 13.5k/13.5k [00:00<00:00, 15.2MB/s]
# mirna_species.txt: 100%|██████████| 29.7k/29.7k [00:00<00:00, 13.7MB/s]
# CPU times: user 11.7 s, sys: 538 ms, total: 12.2 s
# Wall time: 6min 43s

# %% [markdown]
# ## 1. Define the list of genes of interest

# %%
genes = ["SRC", "NOTCH1", "FAK", "CDH1", "CDH2", "VIM", "MAP4K4", "LATS1", "LATS2", "PTK2B"]

# %% [markdown]
# ## 2. Create a network using as input the gene set.
#
# <div class="alert alert-info">
#
# **Note**
#
# NB! If no resource is specified, the default used resource by the package is `omnipath.all_interactions()`. To add new resources, please see the [Add resources](https://omniflow-project.readthedocs.io/en/latest/notebooks/add_resources.html#) tutorial.
#
# </div>

# %% [markdown]
# ### 2A. Import genes as network nodes

# %%
import logging
import sys

# 1. On réinitialise complètement le système de log pour tout intercepter
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# 2. On configure un affichage immédiat dans le Notebook
logging.basicConfig(
    stream=sys.stdout,
    level=logging.DEBUG, # On demande le maximum de détails (DEBUG)
    format='%(asctime)s | %(name)s | %(levelname)s | %(message)s'
)

# 3. On force les bibliothèques bavardes à se montrer
logging.getLogger("pypath").setLevel(logging.DEBUG)
logging.getLogger("omnipath").setLevel(logging.DEBUG)
logging.getLogger("urllib3").setLevel(logging.DEBUG)

print("🔍 Mode 'Loupe' activé. Lance ta cellule Network, les logs vont défiler ici 👇")
# Out:
# 🔍 Mode 'Loupe' activé. Lance ta cellule Network, les logs vont défiler ici 👇

# %%
new_net1 = Network(genes, resources = 'omnipath')
# Out:
# 2026-04-28 19:45:54,785 | root | DEBUG | Initialized `<Downloader[options=Options(url='https://omnipathdb.org', fallback_urls=('http://no-tls.omnipathdb.org',), static_url='http://no-tls.static.omnipathdb.org/resources', license=None, cache=<FileCache[size=0, path='/home/nina/.cache/omnipathdb']>, autoload=True, convert_dtypes=True, num_retries=3, timeout=600.0, chunk_size=8196)]>`
# 2026-04-28 19:45:54,786 | root | DEBUG | Attempting server `https://omnipathdb.org/`.
# 2026-04-28 19:45:54,787 | root | DEBUG | Looking up in cache: `https://omnipathdb.org/interactions?datasets=kinaseextra%2Cligrecextra%2Comnipath%2Cpathwayextra&fields=curation_effort%2Creferences%2Csources&format=tsv` ('0bcb572308e08eb882344c554f1643a4').
# 2026-04-28 19:45:54,788 | root | INFO | Downloading data from `https://omnipathdb.org/interactions?datasets=kinaseextra%2Cligrecextra%2Comnipath%2Cpathwayextra&fields=curation_effort%2Creferences%2Csources&format=tsv`
# 2026-04-28 19:45:54,789 | urllib3.connectionpool | DEBUG | Starting new HTTPS connection (1): omnipathdb.org:443
# 2026-04-28 19:45:54,964 | urllib3.connectionpool | DEBUG | https://omnipathdb.org:443 "GET /interactions?datasets=kinaseextra%2Cligrecextra%2Comnipath%2Cpathwayextra&fields=curation_effort%2Creferences%2Csources&format=tsv HTTP/1.1" 200 None
# 0.00B [00:00, ?B/s]
# 2026-04-28 19:45:57,552 | root | DEBUG | Caching result to `<FileCache[size=0, path='/home/nina/.cache/omnipathdb']>['0bcb572308e08eb882344c554f1643a4']`
# 2026-04-28 19:46:00,327 | dlmachine._manager | INFO | download called url=https://rest.uniprot.org/uniprotkb/stream dest=None
# 2026-04-28 19:46:00,328 | dlmachine._manager | INFO | Starting internal download flow retries=1 dest=None
# 2026-04-28 19:46:00,329 | dlmachine._descriptor | DEBUG | Initializing Descriptor with args=('https://rest.uniprot.org/uniprotkb/stream',) kwargs_keys=['query']
# 2026-04-28 19:46:00,330 | dlmachine._descriptor | DEBUG | Using URL from arguments/kwargs, fname='https://rest.uniprot.org/uniprotkb/stream'
# 2026-04-28 19:46:00,330 | dlmachine._descriptor | INFO | No cainfo provided, using certifi default bundle
# 2026-04-28 19:46:00,331 | dlmachine._descriptor | DEBUG | Descriptor param set: 'cainfo'='/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/certifi/cacert.pem'
# 2026-04-28 19:46:00,332 | dlmachine._descriptor | DEBUG | Descriptor param set: 'baseurl'='https://rest.uniprot.org/uniprotkb/stream'
# 2026-04-28 19:46:00,332 | dlmachine._descriptor | DEBUG | Descriptor param set: 'followlocation'=True
# 2026-04-28 19:46:00,333 | dlmachine._descriptor | DEBUG | Encoding query parameters with 4 entries
# 2026-04-28 19:46:00,333 | dlmachine._descriptor | DEBUG | Descriptor param set: 'qs'='query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true'
# 2026-04-28 19:46:00,334 | dlmachine._descriptor | DEBUG | Descriptor param set: 'url'='https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true'
# 2026-04-28 19:46:00,335 | dlmachine._descriptor | DEBUG | Resolved request URL: https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true
# 2026-04-28 19:46:00,335 | dlmachine._descriptor | DEBUG | Normalized headers list length: 0
# 2026-04-28 19:46:00,336 | dlmachine._descriptor | DEBUG | Descriptor param set: 'headers'=[]
# 2026-04-28 19:46:00,336 | dlmachine._descriptor | INFO | Descriptor initialized for baseurl=https://rest.uniprot.org/uniprotkb/stream post=False has_query=True
# 2026-04-28 19:46:00,337 | dlmachine._manager | DEBUG | Resolved backend class prefix: Requests
# 2026-04-28 19:46:00,338 | dlmachine._manager | DEBUG | Using backend: Requests
# 2026-04-28 19:46:00,339 | dlmachine._manager | DEBUG | Destination uses auto mode: dest=None cache_available=True
# 2026-04-28 19:46:00,339 | dlmachine._manager | DEBUG | Cache is available True
# 2026-04-28 19:46:00,339 | dlmachine._manager | DEBUG | Downloading to buffer False
# 2026-04-28 19:46:00,339 | dlmachine._manager | INFO | Download attempt 1/1
# 2026-04-28 19:46:00,340 | dlmachine._manager | DEBUG | Querying cache for descriptor baseurl=https://rest.uniprot.org/uniprotkb/stream
# 2026-04-28 19:46:00,340 | dlmachine._manager | DEBUG | DL_PARAMS: [headers=[],query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)]]
# 2026-04-28 19:46:00,341 | dlmachine._manager | DEBUG | DESC_PARAMS: [baseurl=https://rest.uniprot.org/uniprotkb/stream,cainfo=/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/certifi/cacert.pem,followlocation=True,headers=[],qs=query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true,query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)],url=https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true]
# 2026-04-28 19:46:00,342 | cachedir._cache | DEBUG | SEARCH
# 2026-04-28 19:46:00,342 | cachedir._cache | DEBUG | Searching cache: [attrs=None,ext=None,filename=None,ids=None,include_removed=False,key=None,label=None,newer_than=None,older_than=None,params=[dl_params=[headers=[],query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)]]],status=[1,3],uri=https://rest.uniprot.org/uniprotkb/stream,version=None]
# 2026-04-28 19:46:00,343 | cachedir._cache | DEBUG | Searching by attributes: {}
# 2026-04-28 19:46:00,343 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_varchar attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND status IN (1, 3)
# 2026-04-28 19:46:00,344 | cachedir._cache | DEBUG | Fetching results from attr_varchar
# 2026-04-28 19:46:00,345 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_int attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND status IN (1, 3)
# 2026-04-28 19:46:00,345 | cachedir._cache | DEBUG | Fetching results from attr_int
# 2026-04-28 19:46:00,346 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_datetime attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND status IN (1, 3)
# 2026-04-28 19:46:00,346 | cachedir._cache | DEBUG | Fetching results from attr_datetime
# 2026-04-28 19:46:00,347 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_float attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND status IN (1, 3)
# 2026-04-28 19:46:00,347 | cachedir._cache | DEBUG | Fetching results from attr_float
# 2026-04-28 19:46:00,348 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, json(value) FROM main LEFT JOIN attr_text attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND status IN (1, 3)
# 2026-04-28 19:46:00,348 | cachedir._cache | DEBUG | Fetching results from attr_text
# 2026-04-28 19:46:00,348 | cachedir._cache | DEBUG | Retrieved 0 results
# 2026-04-28 19:46:00,349 | cachedir._cache | DEBUG | END SEARCH
# 2026-04-28 19:46:00,349 | cachedir._cache | DEBUG | No version found matching criteria
# 2026-04-28 19:46:00,349 | cachedir._cache | DEBUG | CREATE https://rest.uniprot.org/uniprotkb/stream
# 2026-04-28 19:46:00,350 | cachedir._cache | DEBUG | Creating new version for item [attrs=[dl_descriptor=[baseurl=https://rest.uniprot.org/uniprotkb/stream,cainfo=/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/certifi/cacert.pem,followlocation=True,headers=[],qs=query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true,query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)],url=https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true]],ext=None,filename=None,label=None,params=[_uri=https://rest.uniprot.org/uniprotkb/stream,dl_params=[headers=[],query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)]]],status=0,uri=https://rest.uniprot.org/uniprotkb/stream]
# 2026-04-28 19:46:00,350 | cachedir._cache | DEBUG | Looking up existing versions of item `https://rest.uniprot.org/uniprotkb/stream`
# 2026-04-28 19:46:00,351 | cachedir._cache | DEBUG | SEARCH
# 2026-04-28 19:46:00,352 | cachedir._cache | DEBUG | Searching cache: [attrs=None,ext=None,filename=None,ids=None,include_removed=False,key=None,label=None,newer_than=None,older_than=None,params=[_uri=https://rest.uniprot.org/uniprotkb/stream,dl_params=[headers=[],query=[compressed=true,fields=accession,gene_primary,format=tsv,query=(reviewed:true AND organism_id:9606)]]],status=None,uri=https://rest.uniprot.org/uniprotkb/stream,version=None]
# 2026-04-28 19:46:00,352 | cachedir._cache | DEBUG | Searching by attributes: {}
# 2026-04-28 19:46:00,353 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_varchar attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2
# 2026-04-28 19:46:00,357 | cachedir._cache | DEBUG | Fetching results from attr_varchar
# 2026-04-28 19:46:00,358 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_int attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2
# 2026-04-28 19:46:00,359 | cachedir._cache | DEBUG | Fetching results from attr_int
# 2026-04-28 19:46:00,360 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_datetime attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2
# 2026-04-28 19:46:00,362 | cachedir._cache | DEBUG | Fetching results from attr_datetime
# 2026-04-28 19:46:00,363 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_float attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2
# 2026-04-28 19:46:00,364 | cachedir._cache | DEBUG | Fetching results from attr_float
# 2026-04-28 19:46:00,364 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, json(value) FROM main LEFT JOIN attr_text attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2
# 2026-04-28 19:46:00,365 | cachedir._cache | DEBUG | Fetching results from attr_text
# 2026-04-28 19:46:00,366 | cachedir._cache | DEBUG | Retrieved 0 results
# 2026-04-28 19:46:00,366 | cachedir._cache | DEBUG | END SEARCH
# 2026-04-28 19:46:00,366 | cachedir._cache | DEBUG | No existing version found.
# 2026-04-28 19:46:00,367 | cachedir._cache | DEBUG | Next version: e14269b29ce60870c271d375c35e1a7b-1
# 2026-04-28 19:46:00,367 | cachedir._cache | DEBUG | Executing query:  INSERT INTO main ( item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count ) VALUES ( 'e14269b29ce60870c271d375c35e1a7b', "e14269b29ce60870c271d375c35e1a7b-1", 1, 0, 'stream', NULL, '2026-04-28 19:46:00', NULL, NULL, '2026-04-28 19:46:00', 0, 0 )
# 2026-04-28 19:46:00,374 | cachedir._cache | DEBUG | Executing query: SELECT id FROM main WHERE version_id = "e14269b29ce60870c271d375c35e1a7b-1"
# 2026-04-28 19:46:00,377 | cachedir._cache | DEBUG | Creating attributes in attr_varchar
# 2026-04-28 19:46:00,379 | cachedir._cache | DEBUG | Executing query: INSERT INTO attr_varchar ( id, namespace, keyvar, name, value ) VALUES (3, 'dl_descriptor', 0, "url", 'https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true'), (3, 'dl_descriptor', 0, "cainfo", '/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/certifi/cacert.pem'), (3, 'dl_descriptor', 0, "baseurl", 'https://rest.uniprot.org/uniprotkb/stream'), (3, 'dl_descriptor', 0, "qs", 'query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true'), (3, NULL, 1, "_uri", 'https://rest.uniprot.org/uniprotkb/stream')
# 2026-04-28 19:46:00,386 | cachedir._cache | DEBUG | Creating attributes in attr_int
# 2026-04-28 19:46:00,388 | cachedir._cache | DEBUG | Creating attributes in attr_datetime
# 2026-04-28 19:46:00,390 | cachedir._cache | DEBUG | Creating attributes in attr_float
# 2026-04-28 19:46:00,390 | cachedir._cache | DEBUG | Creating attributes in attr_text
# 2026-04-28 19:46:00,391 | cachedir._cache | DEBUG | Executing query: INSERT INTO attr_text ( id, namespace, keyvar, name, value ) VALUES (3, 'dl_descriptor', 0, "query", json('{"query": "(reviewed:true AND organism_id:9606)", "format": "tsv", "fields": "accession,gene_primary", "compressed": "true"}')), (3, 'dl_descriptor', 0, "headers", json('[]')), (3, 'dl_params', 1, "query", json('{"query": "(reviewed:true AND organism_id:9606)", "format": "tsv", "fields": "accession,gene_primary", "compressed": "true"}')), (3, 'dl_params', 1, "headers", json('[]'))
# 2026-04-28 19:46:00,400 | cachedir._cache | DEBUG | Successfully created: e14269b29ce60870c271d375c35e1a7b-1
# 2026-04-28 19:46:00,401 | cachedir._cache | DEBUG | END CREATE
# 2026-04-28 19:46:00,403 | dlmachine._manager | INFO | Cache item selected key=e14269b29ce60870c271d375c35e1a7b status=0
# 2026-04-28 19:46:00,407 | dlmachine._manager | DEBUG | Cache returned item key=e14269b29ce60870c271d375c35e1a7b status=0 path=/home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1
# 2026-04-28 19:46:00,409 | dlmachine._downloader | DEBUG | Initializing RequestsDownloader destination='/home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1'
# 2026-04-28 19:46:00,411 | dlmachine._downloader | DEBUG | Set destination to '/home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1'
# 2026-04-28 19:46:00,413 | dlmachine._manager | INFO | No valid version in cache, starting download
# 2026-04-28 19:46:00,416 | dlmachine._manager | DEBUG | Reporting started download for cache item key=e14269b29ce60870c271d375c35e1a7b
# 2026-04-28 19:46:00,420 | cachedir._cache | DEBUG | SEARCH
# 2026-04-28 19:46:00,421 | cachedir._cache | DEBUG | Searching cache: [attrs=None,ext=None,filename=None,ids=None,include_removed=False,key=e14269b29ce60870c271d375c35e1a7b,label=None,newer_than=None,older_than=None,params=None,status=None,uri=None,version=1]
# 2026-04-28 19:46:00,424 | cachedir._cache | DEBUG | Searching by attributes: {}
# 2026-04-28 19:46:00,426 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_varchar attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,430 | cachedir._cache | DEBUG | Fetching results from attr_varchar
# 2026-04-28 19:46:00,432 | cachedir._cache | DEBUG | Found version: `e14269b29ce60870c271d375c35e1a7b-1`
# 2026-04-28 19:46:00,433 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_int attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,436 | cachedir._cache | DEBUG | Fetching results from attr_int
# 2026-04-28 19:46:00,438 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_datetime attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,441 | cachedir._cache | DEBUG | Fetching results from attr_datetime
# 2026-04-28 19:46:00,443 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_float attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,446 | cachedir._cache | DEBUG | Fetching results from attr_float
# 2026-04-28 19:46:00,448 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, json(value) FROM main LEFT JOIN attr_text attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,451 | cachedir._cache | DEBUG | Fetching results from attr_text
# 2026-04-28 19:46:00,453 | cachedir._cache | DEBUG | Executing query: UPDATE main SET last_search = DATETIME("now"), search_count = search_count + 1 WHERE id IN (3);
# 2026-04-28 19:46:00,461 | cachedir._cache | DEBUG | Retrieved 1 results
# 2026-04-28 19:46:00,463 | cachedir._cache | DEBUG | END SEARCH
# 2026-04-28 19:46:00,464 | cachedir._cache | DEBUG | Updating 1 items
# 2026-04-28 19:46:00,464 | cachedir._cache | DEBUG | Executing query: UPDATE main SET status = 1 WHERE id IN (3);
# 2026-04-28 19:46:00,475 | cachedir._cache | DEBUG | Updating attributes in attr_varchar
# 2026-04-28 19:46:00,477 | cachedir._cache | DEBUG | Updating attributes in attr_int
# 2026-04-28 19:46:00,478 | cachedir._cache | DEBUG | Updating attributes in attr_datetime
# 2026-04-28 19:46:00,480 | cachedir._cache | DEBUG | Updating attributes in attr_float
# 2026-04-28 19:46:00,480 | cachedir._cache | DEBUG | Updating attributes in attr_text
# 2026-04-28 19:46:00,481 | cachedir._cache | DEBUG | Finished updating attributes
# 2026-04-28 19:46:00,481 | cachedir._cache | DEBUG | SEARCH
# 2026-04-28 19:46:00,482 | cachedir._cache | DEBUG | Searching cache: [attrs=None,ext=None,filename=None,ids=None,include_removed=False,key=e14269b29ce60870c271d375c35e1a7b,label=None,newer_than=None,older_than=None,params=None,status=None,uri=None,version=1]
# 2026-04-28 19:46:00,482 | cachedir._cache | DEBUG | Searching by attributes: {}
# 2026-04-28 19:46:00,483 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_varchar attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,484 | cachedir._cache | DEBUG | Fetching results from attr_varchar
# 2026-04-28 19:46:00,485 | cachedir._cache | DEBUG | Found version: `e14269b29ce60870c271d375c35e1a7b-1`
# 2026-04-28 19:46:00,486 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_int attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,487 | cachedir._cache | DEBUG | Fetching results from attr_int
# 2026-04-28 19:46:00,487 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_datetime attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,488 | cachedir._cache | DEBUG | Fetching results from attr_datetime
# 2026-04-28 19:46:00,488 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_float attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,488 | cachedir._cache | DEBUG | Fetching results from attr_float
# 2026-04-28 19:46:00,489 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, json(value) FROM main LEFT JOIN attr_text attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,489 | cachedir._cache | DEBUG | Fetching results from attr_text
# 2026-04-28 19:46:00,491 | cachedir._cache | DEBUG | Executing query: UPDATE main SET last_search = DATETIME("now"), search_count = search_count + 1 WHERE id IN (3);
# 2026-04-28 19:46:00,496 | cachedir._cache | DEBUG | Retrieved 1 results
# 2026-04-28 19:46:00,497 | cachedir._cache | DEBUG | END SEARCH
# 2026-04-28 19:46:00,497 | cachedir._cache | DEBUG | Updating 1 items
# 2026-04-28 19:46:00,498 | cachedir._cache | DEBUG | Updating attributes in attr_varchar
# 2026-04-28 19:46:00,498 | cachedir._cache | DEBUG | Executing query: UPDATE attr_varchar SET value = '2026-04-28 19:46:00' WHERE id IN (3) AND name = "download_started" AND namespace = NULL
# 2026-04-28 19:46:00,499 | cachedir._cache | DEBUG | Executing query: SELECT id FROM attr_varchar WHERE id IN (3) AND name = "download_started" AND namespace = NULL
# 2026-04-28 19:46:00,500 | cachedir._cache | DEBUG | Executing query: INSERT INTO attr_varchar (id, namespace, keyvar, name, value) VALUES (3, NULL, 0, "download_started", '2026-04-28 19:46:00')
# 2026-04-28 19:46:00,506 | cachedir._cache | DEBUG | Updating attributes in attr_int
# 2026-04-28 19:46:00,506 | cachedir._cache | DEBUG | Updating attributes in attr_datetime
# 2026-04-28 19:46:00,507 | cachedir._cache | DEBUG | Updating attributes in attr_float
# 2026-04-28 19:46:00,507 | cachedir._cache | DEBUG | Updating attributes in attr_text
# 2026-04-28 19:46:00,507 | cachedir._cache | DEBUG | Finished updating attributes
# 2026-04-28 19:46:00,508 | cachedir._cache | DEBUG | SEARCH
# 2026-04-28 19:46:00,509 | cachedir._cache | DEBUG | Searching cache: [attrs=None,ext=None,filename=None,ids=None,include_removed=False,key=e14269b29ce60870c271d375c35e1a7b,label=None,newer_than=None,older_than=None,params=None,status=None,uri=None,version=1]
# 2026-04-28 19:46:00,509 | cachedir._cache | DEBUG | Searching by attributes: {}
# 2026-04-28 19:46:00,509 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_varchar attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,511 | cachedir._cache | DEBUG | Fetching results from attr_varchar
# 2026-04-28 19:46:00,511 | cachedir._cache | DEBUG | Found version: `e14269b29ce60870c271d375c35e1a7b-1`
# 2026-04-28 19:46:00,512 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_int attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,513 | cachedir._cache | DEBUG | Fetching results from attr_int
# 2026-04-28 19:46:00,514 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_datetime attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,515 | cachedir._cache | DEBUG | Fetching results from attr_datetime
# 2026-04-28 19:46:00,516 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, value FROM main LEFT JOIN attr_float attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,517 | cachedir._cache | DEBUG | Fetching results from attr_float
# 2026-04-28 19:46:00,517 | cachedir._cache | DEBUG | Executing query: SELECT main.id, item_id, version_id, version, status, file_name, label, date, ext, last_read, last_search, read_count, search_count, namespace, keyvar, name, json(value) FROM main LEFT JOIN attr_text attr ON main.id = attr.id WHERE item_id = "e14269b29ce60870c271d375c35e1a7b" AND status != -1 AND status != -2 AND version IN (1)
# 2026-04-28 19:46:00,518 | cachedir._cache | DEBUG | Fetching results from attr_text
# 2026-04-28 19:46:00,520 | cachedir._cache | DEBUG | Executing query: UPDATE main SET last_search = DATETIME("now"), search_count = search_count + 1 WHERE id IN (3);
# 2026-04-28 19:46:00,526 | cachedir._cache | DEBUG | Retrieved 1 results
# 2026-04-28 19:46:00,527 | cachedir._cache | DEBUG | END SEARCH
# 2026-04-28 19:46:00,527 | cachedir._cache | DEBUG | Updating 1 items
# 2026-04-28 19:46:00,528 | cachedir._cache | DEBUG | Executing query: UPDATE main SET date = '2026-04-28 19:46:00' WHERE id IN (3);
# 2026-04-28 19:46:00,529 | cachedir._cache | DEBUG | Updating attributes in attr_varchar
# 2026-04-28 19:46:00,530 | cachedir._cache | DEBUG | Updating attributes in attr_int
# 2026-04-28 19:46:00,530 | cachedir._cache | DEBUG | Updating attributes in attr_datetime
# 2026-04-28 19:46:00,531 | cachedir._cache | DEBUG | Updating attributes in attr_float
# 2026-04-28 19:46:00,532 | cachedir._cache | DEBUG | Updating attributes in attr_text
# 2026-04-28 19:46:00,532 | cachedir._cache | DEBUG | Finished updating attributes
# 2026-04-28 19:46:00,533 | dlmachine._downloader | INFO | Setting up downloader: RequestsDownloader
# 2026-04-28 19:46:00,533 | dlmachine._downloader | DEBUG | Creating Requests Session and Request
# 2026-04-28 19:46:00,535 | dlmachine._downloader | INFO | Initialized requests Session and Request objects
# 2026-04-28 19:46:00,536 | dlmachine._downloader | DEBUG | Setting parameters for Requests
# 2026-04-28 19:46:00,536 | dlmachine._downloader | DEBUG | Setting URL: `https://rest.uniprot.org/uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true`
# 2026-04-28 19:46:00,537 | dlmachine._downloader | DEBUG | Requests timeout config=(None, None)
# 2026-04-28 19:46:00,538 | dlmachine._downloader | DEBUG | Configured requests GET request
# 2026-04-28 19:46:00,538 | dlmachine._downloader | DEBUG | send_args: [[allow_redirects=True,timeout=[None,None]]]
# 2026-04-28 19:46:00,539 | dlmachine._downloader | DEBUG | Opening destination for writing /home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1
# 2026-04-28 19:46:00,541 | dlmachine._downloader | INFO | Opened file destination: /home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1
# 2026-04-28 19:46:00,542 | dlmachine._downloader | DEBUG | Setting request headers:
# 2026-04-28 19:46:00,542 | dlmachine._descriptor | DEBUG | Converting 0 headers to dict
# 2026-04-28 19:46:00,543 | dlmachine._downloader | DEBUG | Configured requests headers count=0
# 2026-04-28 19:46:00,543 | dlmachine._downloader | DEBUG | Response headers container initialized
# 2026-04-28 19:46:00,544 | dlmachine._downloader | DEBUG | Requests response headers placeholder initialized
# 2026-04-28 19:46:00,545 | dlmachine._downloader | DEBUG | Finished setting up the downloader
# 2026-04-28 19:46:00,545 | dlmachine._downloader | INFO | Starting requests download to destination='/home/nina/.cache/pypath/e14269b29ce60870c271d375c35e1a7b-1'
# 2026-04-28 19:46:00,547 | urllib3.connectionpool | DEBUG | Starting new HTTPS connection (1): rest.uniprot.org:443
# 2026-04-28 19:46:02,236 | urllib3.connectionpool | DEBUG | https://rest.uniprot.org:443 "GET /uniprotkb/stream?query=%28reviewed%3Atrue+AND+organism_id%3A9606%29&format=tsv&fields=accession%2Cgene_primary&compressed=true HTTP/1.1" 200 None
# 2026-04-28 19:47:02,289 | dlmachine._downloader | ERROR | Requests download failed
# Traceback (most recent call last):
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py", line 822, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py", line 1250, in stream
#     yield from self.read_chunked(amt, decode_content=decode_content)
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py", line 1418, in read_chunked
#     self._update_chunk_length()
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py", line 1344, in _update_chunk_length
#     raise ProtocolError("Response ended prematurely") from None
# urllib3.exceptions.ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/dlmachine/_downloader.py", line 813, in download
#     with self.session.send(req, **self.send_args) as resp:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/sessions.py", line 749, in send
#     r.content
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py", line 904, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nina/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py", line 824, in generate
#     raise ChunkedEncodingError(e)
# requests.exceptions.ChunkedEncodingError: Response ended prematurely
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     821 try:
# --> 822     yield from self.raw.stream(chunk_size, decode_content=True)
#     823 except ProtocolError as e:
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py:1418, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1417 else:
# -> 1418     self._update_chunk_length()
#    1419     if self.chunk_left == 0:
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/urllib3/response.py:1344, in HTTPResponse._update_chunk_length(self)
#    1342 else:
#    1343     # Truncated at start of next chunk
# -> 1344     raise ProtocolError("Response ended prematurely") from None
#
# ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 new_net1 = Network(genes, resources = 'omnipath')
#
# File ~/Dev_Projects/Neko/neko/core/network.py:119, in Network.__init__(self, initial_nodes, sif_file, resources)
#     117 self._max_history: Optional[int] = None
#     118 self._is_initializing = True
# --> 119 self._populate()
#     120 self._is_initializing = False
#
# File ~/Dev_Projects/Neko/neko/core/network.py:172, in Network._populate(self)
#     170 nodes_found = []
#     171 for node in self.initial_nodes:
# --> 172     if self.add_node(node):
#     173         nodes_found.append(node)
#     174 self.initial_nodes = nodes_found
#
# File ~/Dev_Projects/Neko/neko/core/network.py:44, in _record_state_operation.<locals>.wrapper(self, *args, **kwargs)
#      41     return method(self, *args, **kwargs)
#      43 if getattr(self, "_is_initializing", False):
# ---> 44     return method(self, *args, **kwargs)
#      46 depth = getattr(self, "_auto_state_depth", 0)
#      47 self._auto_state_depth = depth + 1
#
# File ~/Dev_Projects/Neko/neko/core/network.py:292, in Network.add_node(self, node, from_sif)
#     290     self.initial_nodes = list(set(self.initial_nodes))
#     291     return True
# --> 292 complex_string, genesymbol, uniprot = mapping_node_identifier(node)
#     293 if complex_string:
#     294     new_entry = {"Genesymbol": complex_string, "Uniprot": node, "Type": "NaN"}
#
# File ~/Dev_Projects/Neko/neko/core/tools.py:103, in mapping_node_identifier(node)
#     100 genesymbol = None
#     101 uniprot = None
# --> 103 node_id = mapping.id_from_label0(node)
#     105 if node_id:
#     106     # Convert UniProt ID to gene symbol
#     107     uniprot = node_id
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:3793, in id_from_label0(label, label_id_type, ncbi_tax_id)
#    3787 """
#    3788 For a label (e.g. Gene Symbol) returns a single ID (e.g. UniProt IDs).
#    3789 """
#    3791 mapper = get_mapper()
# -> 3793 return mapper.id_from_label0(
#    3794     label = label,
#    3795     label_id_type = label_id_type,
#    3796     ncbi_tax_id = ncbi_tax_id,
#    3797 )
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:2904, in Mapper.id_from_label0(self, label, label_id_type, ncbi_tax_id)
#    2896 def id_from_label0(
#    2897         self,
#    2898         label,
#    2899         label_id_type = 'genesymbol',
#    2900         ncbi_tax_id = None,
#    2901     ):
#    2903     return next(
# -> 2904         self.id_from_label(
#    2905             label = label,
#    2906             label_id_type = label_id_type,
#    2907             ncbi_tax_id = ncbi_tax_id
#    2908         ).__iter__()
#    2909     )
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:2887, in Mapper.id_from_label(self, label, label_id_type, ncbi_tax_id)
#    2878 def id_from_label(
#    2879         self,
#    2880         label,
#    2881         label_id_type = 'genesymbol',
#    2882         ncbi_tax_id = None,
#    2883     ):
#    2885     if label_id_type in self.label_type_to_id_type:
# -> 2887         ids = self.map_name(
#    2888             label,
#    2889             label_id_type,
#    2890             self.label_type_to_id_type[label_id_type],
#    2891             ncbi_tax_id = ncbi_tax_id,
#    2892         )
#    2894     return ids or {label}
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath_common/_misc.py:2953, in ignore_unhashable.<locals>.wrapper(*args, **kwargs)
#    2950 @functools.wraps(func, assigned = attributes)
#    2951 def wrapper(*args, **kwargs):
#    2952     try:
# -> 2953         return func(*args, **kwargs)
#    2954     except TypeError as error:
#    2955         if 'unhashable type' in str(error):
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:2068, in Mapper.map_name(self, name, id_type, target_id_type, ncbi_tax_id, strict, expand_complexes, uniprot_cleanup)
#    2054     mapped_names = self.chain_map(
#    2055         name = name,
#    2056         id_type = id_type,
#    (...)   2062         uniprot_cleanup = uniprot_cleanup,
#    2063     )
#    2065 else:
#    2066
#    2067     # all the other ID types
# -> 2068     mapped_names = self._map_name(
#    2069         name = name,
#    2070         id_type = id_type,
#    2071         target_id_type = target_id_type,
#    2072         ncbi_tax_id = ncbi_tax_id,
#    2073     )
#    2075 # as ID translation tables for PRO IDs are not organism specific
#    2076 # we need an extra step to limit the results to the target organism
#    2077 if id_type == 'pro' and target_id_type == 'uniprot':
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:2600, in Mapper._map_name(self, name, id_type, target_id_type, ncbi_tax_id)
#    2593 """
#    2594 Once we have defined the name type and the target name type,
#    2595 this function looks it up in the most suitable dictionary.
#    2596 """
#    2598 ncbi_tax_id = ncbi_tax_id or self.ncbi_tax_id
# -> 2600 tbl = self.which_table(
#    2601     id_type,
#    2602     target_id_type,
#    2603     ncbi_tax_id = ncbi_tax_id,
#    2604 )
#    2606 return tbl[name] if tbl else set()
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:1624, in Mapper.which_table(self, id_type, target_id_type, load, ncbi_tax_id)
#    1613 if resource:
#    1615     self._log(
#    1616         'Chosen built-in defined ID translation table: '
#    1617         'resource=%s, id_type_a=%s, id_type_b=%s' % (
#    (...)   1621         )
#    1622     )
# -> 1624     self.load_mapping(
#    1625         resource = resource,
#    1626         load_a_to_b = load_a_to_b,
#    1627         load_b_to_a = load_b_to_a,
#    1628         ncbi_tax_id = ncbi_tax_id,
#    1629     )
#    1631     tbl = check_loaded()
#    1633     break
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:3298, in Mapper.load_mapping(self, resource, **kwargs)
#    3285 ncbi_tax_id = kwargs.get('ncbi_tax_id', resource.ncbi_tax_id)
#    3287 self._log(
#    3288     'Loading mapping table for organism `%s` '
#    3289     'with identifiers `%s` and `%s`, '
#    (...)   3295     )
#    3296 )
# -> 3298 reader = MapReader(param = resource, **kwargs)
#    3300 a_to_b = reader.mapping_table_a_to_b
#    3301 b_to_a = reader.mapping_table_b_to_a
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:281, in MapReader.__init__(self, param, ncbi_tax_id, entity_type, load_a_to_b, load_b_to_a, uniprots, lifetime, resource_id_types)
#     278 self.uniprots = uniprots
#     279 self._resource_id_types = resource_id_types
# --> 281 self.load()
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:311, in MapReader.load(self)
#     306     self.read_cache()
#     308 if not self.tables_loaded():
#     309
#     310     # read from the original source
# --> 311     self.read()
#     313     if self.tables_loaded():
#     314
#     315         # write cache only at successful loading
#     316         self.write_cache()
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:473, in MapReader.read(self)
#     469 method = 'read_mapping_%s' % self.source_type
#     471 if hasattr(self, method):
# --> 473     getattr(self, method)()
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/utils/mapping.py:916, in MapReader.read_mapping_uniprot(self)
#     914 protein_name = self.param.field == 'protein names'
#     915 query.name_process = not protein_name and not trembl
# --> 916 data = query.perform()
#     918 if not query.name_process:
#     920     def maybe_split(v):
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/inputs/uniprot.py:698, in UniprotQuery.perform(self)
#     694 maybe_empty, raw_result = itertools.tee(self)
#     696 try:
# --> 698     _ = next(maybe_empty)
#     700 except StopIteration:
#     702     if self.fields:
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/pypath/inputs/uniprot.py:658, in UniprotQuery.__iter__(self)
#     656 def __iter__(self):
# --> 658     path = dm.download(
#     659         self._baseurl,
#     660         query = self._get,
#     661     )
#     663     if not path and not self.fail_on_empty:
#     664         return
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/dlmachine/_manager.py:146, in DownloadManager.download(self, url, dest, newer_than, older_than, check_freshness, check_method, force_download, keep_old, **kwargs)
#     138         post_info = f' POST(form, keys={sorted(query.keys()) if isinstance(query, dict) else "non-dict"})'
#     140 logger.info(
#     141     'download called url=%s dest=%r%s',
#     142     url if isinstance(url, str) else type(url).__name__,
#     143     dest,
#     144     post_info,
#     145 )
# --> 146 *_, dest = self._download(
#     147     url,
#     148     dest=dest,
#     149     newer_than=newer_than,
#     150     older_than=older_than,
#     151     check_freshness=check_freshness,
#     152     check_method=check_method,
#     153     force_download=force_download,
#     154     keep_old=keep_old,
#     155     **kwargs,
#     156 )
#     158 return dest
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/dlmachine/_manager.py:383, in DownloadManager._download(self, url, dest, newer_than, older_than, check_freshness, check_method, force_download, keep_old, retries, **kwargs)
#     380 logger.info('No valid version in cache, starting download')
#     382 self._report_started(item)
# --> 383 downloader.download()
#     384 self._report_finished(item, downloader, desc)
#     386 if downloader.ok:
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/dlmachine/_downloader.py:813, in RequestsDownloader.download(self)
#     810 req = self.request.prepare()
#     812 try:
# --> 813     with self.session.send(req, **self.send_args) as resp:
#     815         self.response = resp
#     816         self._expected_size = int(resp.headers.get('Content-Length', 0))
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/sessions.py:749, in Session.send(self, request, **kwargs)
#     746         pass
#     748 if not stream:
# --> 749     r.content
#     751 return r
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py:904, in Response.content(self)
#     902         self._content = None
#     903     else:
# --> 904         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     906 self._content_consumed = True
#     907 # don't need to release the connection; that's been handled by urllib3
#     908 # since we exhausted the data.
#
# File ~/Dev_Projects/Neko/.venv/lib/python3.12/site-packages/requests/models.py:824, in Response.iter_content.<locals>.generate()
#     822     yield from self.raw.stream(chunk_size, decode_content=True)
#     823 except ProtocolError as e:
# --> 824     raise ChunkedEncodingError(e)
#     825 except DecodeError as e:
#     826     raise ContentDecodingError(e)
#
# ChunkedEncodingError: Response ended prematurely

# %%
#Print node dataframe
new_net1.nodes

# %% [markdown]
# ### 2B. Explore if the nodes are connected without introducing new intermidiate nodes

# %%
# %%time
new_net1.connect_nodes(only_signed=True, consensus_only=True)

# %% [markdown]
# ### 2C. Visualize the network with the following command.
#
# The network picture is also exported in the working repository, in pdf format.

# %%
visualizer = NetworkVisualizer(new_net1, color_by='effect', noi=True)
visualizer.render()

# %% [markdown]
# ### 2D. Connect disconnected nodes by importing intermediate nodes.
#
# The parameter _*maxlen*_ sets the maximum length of the paths to be searched of.
#
# The parameter _*algorithm*_ sets the base algorithm to use when looking for paths in the resources. It can be 'bfs' (Breadth-First Search) or 'dfs' (Depth-First Search). The first one is faster but does not always retrieve the shortest path, while the second one retrieves all the possible shortest paths at higher computational cost.
#
# The parameter _*only_signed*_ forces the algorithm to look for just signed interactions.
#
# The parameter _*consensus*_ retrieves those interactions with a sign consensus between the references (when possible).
#
# The parameter _*connect_with_bias*_, changes the base algorithm, making it look for possible connection between all the disconnected node in the network when a new bridge-gene is introduced in the network, biasing the final network topology.

# %%
# %%time
new_net1.complete_connection(maxlen=3, algorithm="bfs", only_signed=True, connect_with_bias=False, consensus=True)

# %% [markdown]
# ## 3. Visualize final network

# %%
#Visualize a specific nodes and 
visualizer1 = NetworkVisualizer(new_net1,color_by='effect', noi=True)
visualizer1.render()

# %%
#Visualize a specific nodes and 
visualizer1 = NetworkVisualizer(new_net1, predefined_node = "SRC",color_by='effect')
visualizer1.render()

# %%
#We can access to the edges of the network
new_net1.edges
